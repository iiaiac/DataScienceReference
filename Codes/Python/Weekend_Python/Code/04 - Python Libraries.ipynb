# %% [markdown]
# <p style="text-align: center;"><img src="https://www.python.org/static/community_logos/python-logo-master-v3-TM-flattened.png" alt="" width="444" height="146" /></p>

# %% [markdown]
# <a class="anchor" id="Home"></a>
# ## Table of Content
# * [Libraries in Python](#Libraries-in-Python)
# * [Tutorial](#Tutorial)
# * [Installing a Library](#Installing-a-Library)
# * [Importing a Library](#Importing-a-Library)
# * [Aliasing a Library](#Aliasing-a-Library)
# * [Python Data Science Ecosystem](#Python-Data-Science-Ecosystem)

# %% [markdown]
# ### Libraries in Python <a class="anchor" id="Libraries-in-Python"></a>
#
# ### <p><strong><span style="color: #ff0000;">A Python library is a reusable chunk of code that you may want to include in your programs/ projects.</span></strong></p>

# %% [markdown]
# [Top](#Home)

# %% [markdown]
# ### Tutorial <a class="anchor" id="Tutorial"></a>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('LepMvJdr2-w', width=960, height=540)

# %% [markdown]
# [Top](#Home)

# %% [markdown]
# ### Installing a Library (Example pyserial) <a class="anchor" id="Installing-a-Library"></a>
#
# <p><img src="https://i.ytimg.com/vi/Z_Kxg-EYvxM/maxresdefault.jpg" alt="" width="498" height="280" /></p>

# %% [markdown]
# [Top](#Home)

# %% [markdown]
# ### Importing a Library <a class="anchor" id="Importing-a-Library"></a>
#
# <p><strong><span style="color: #ff0000;"><img src="https://cdn.journaldev.com/wp-content/uploads/2017/12/python-os-import.png" alt="" width="516" height="164" /></span></strong></p>

# %% [markdown]
# [Top](#Home)

# %% [markdown]
# ### Aliasing a Library <a class="anchor" id="Aliasing-a-Library"></a>

# %%
import pandas as pd

# %% [markdown]
# [Top](#Home)

# %% [markdown]
# ### Python Data Science Ecosystem  <a class="anchor" id="Python-Data-Science-Ecosystem"></a>
#
# <p><img src="https://i2.wp.com/www.datasciencelearner.com/wp-content/uploads/2020/07/Complete-Python-Libraries-for-Data-Science-Infographic-scaled.jpg?ssl=1" alt="" width="2560" height="1317" /></p>

# %% [markdown]
# [Top](#Home)

# %% [markdown]
# ### <p style="text-align: center;"><span style="text-decoration: underline;"><strong><span style="color: #ff0000; text-decoration: underline;">Build your own package in Python</span></strong></span></p>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('7GXaobCrBb4', width=960, height=540)

# %% [markdown]
# [Top](#Home)
