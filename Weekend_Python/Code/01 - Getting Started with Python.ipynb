# %% [markdown]
# <p style="text-align: center;"><img src="https://www.python.org/static/community_logos/python-logo-master-v3-TM-flattened.png" alt="" width="444" height="146" /></p>

# %% [markdown]
# <a class="anchor" id="Home"></a>
# ## Table of Content
# * [Getting and Setting Python](#Getting-Python)
# * [Data Types](#Data-Types)
#     * [Youtube Tutorial](#Data-Type-Tutorial)
# * [Taking input from User](#User-input)
# * [Working with Lists](#Working-with-List)
#     * [Tutorial](#Working-with-List-Tutorial)
# * [Working with Dictionary](#Working-with-Dictionary)
#     * [Tutorial](#Working-with-Dictionary-Tutorial)

# %% [markdown]
# ### Download Python and It's Environment Tools <a class="anchor" id="Getting-Python"></a>
#
# <p><a href="https://www.python.org/downloads/" target="_blank">Download Python</a> |&nbsp;<a href="https://docs.conda.io/en/latest/miniconda.html" target="_blank">Download Conda</a> | <a href="https://www.spyder-ide.org/" target="_blank">Download Spyder</a></p>
# <p><a href="https://www.anaconda.com/products/individual" target="_blank">Download Anaconda</a></p>

# %% [markdown]
# <p><h1><span style="color: #ff0000;"><strong>Here, everything starts with Zero not with One and Indentation Matters</strong></span></h1></p>
# <p><h1><span style="color: #ff0000;"><strong>It's Case Sensitive, FOO foo and Foo are different !!</strong></span></h1></p>

# %% [markdown]
# ### Data Types <a class="anchor" id="Data-Types"></a>
#
# <ul>
# <li>Numeric</li>
# <li>Character</li>
# <li>Logical</li>
# <li>Lists</li>
# <li>Dictonary</li>
# </ul>
#
# [Top](#Home)

# %% [markdown]
# ### Tutorial <a class="anchor" id="Data-Type-Tutorial"></a>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('6yrsX752CWk', width=960, height=540)

# %% [markdown]
# [Top](#Home)
# #### Taking inputs from the user <a class="anchor" id="User-input"></a>

# %%
user = input('Please Enter Your Name : ')
print('Hi '+ user)
# Out:
# Please Enter Your Name : Anant
# Hi Anant

# %% [markdown]
# [Top](#Home)
# ### Working with Lists <a class="anchor" id="Working-with-List"></a>

# %% [markdown]
# #### Tutorial <a class="anchor" id="Working-with-List-Tutorial"></a>

# %%
YouTubeVideo('9OeznAkyQz4', width=960, height=540)

# %% [markdown]
# [Top](#Home)

# %%
# Defining a list
List1 = [1, 2, 3]
List2 = [4, 5, 6]

# %%
# Joining two lists
List1 + List2
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# Surprise (list can hold all the data types)
myList = [1, 2, 3.0, 4.75, 'A', 'B', True]
print(myList)
# Out:
# [1, 2, 3.0, 4.75, 'A', 'B', True]

# %%
# Getting Length of a List
len(myList)
# Out:
# 7

# %%
# Accessing an element in a List
myList[-1]
# Out:
# True

# %% [markdown]
# [Top](#Home)
# ### Working with Dictionary <a class="anchor" id="Working-with-Dictionary"></a>

# %% [markdown]
# #### Tutorial <a class="anchor" id="Working-with-Dictionary-Tutorial"></a>

# %%
YouTubeVideo('rZjhId0VkuY', width=960, height=540)

# %% [markdown]
# [Top](#Home)

# %%
# Creating a dictionary
myDictionary = {11: 'Delhi', 22: 'Mumbai', 33: 'Kolkata', 44:'Chennai'}
myDictionary
# Out:
# {11: 'Delhi', 22: 'Mumbai', 33: 'Kolkata', 44: 'Chennai'}

# %%
# Length of a dictionary
len(myDictionary)
# Out:
# 4

# %%
# access an element in a dictionary
myDictionary.get(22)
# Out:
# 'Mumbai'

# %% [markdown]
# [Top](#Home)
